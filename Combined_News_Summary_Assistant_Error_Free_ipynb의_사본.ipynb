# %% [markdown]
# <a href="https://colab.research.google.com/github/kjk1020/-/blob/master/Combined_News_Summary_Assistant_Error_Free_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Combined News Summary Assistant
# This notebook collects articles from multiple sources, summarizes them, and displays the output.

# %%
# !pip install newspaper3k feedparser transformers pdfminer.six schedule
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 57.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 89.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 10.1 MB/s eta 0:00:00
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13539 sha256=04ff1ad0cbfdc8222116400f0bb392038e6a2d3c26b1a87189afa67cb78bc960
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3342 sha256=7d578486d4b61c414d6cf321f91be58423207197b2787ae1a5b6237e2309a677
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
# ...

# %%
import feedparser
from transformers import pipeline
import schedule
import time

# Initialize the summarizer
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...

# %%
def fetch_and_summarize():
    # Fetch articles from The Guardian's RSS feed
    rss_url_guardian = "https://www.theguardian.com/environment/rss"
    feed_guardian = feedparser.parse(rss_url_guardian)

    print("\n--- The Guardian Articles ---\n")
    for entry in feed_guardian.entries[:5]:  # Limit to 5 articles
        title = entry.title
        link = entry.link
        content = entry.summary

        # Generate a short summary
        summary = summarizer(content, max_length=100, min_length=30, do_sample=False)

        # Display the result
        print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# %%
fetch_and_summarize()
# Out:
# --- The Guardian Articles ---
#
# Title: California fires: 16 killed and 10,000 structures destroyed as blazes continue
# Link: https://www.theguardian.com/us-news/2025/jan/10/fast-dry-winds-california-wildfires
# Summary:  Strong winds and low humidity continue as five fires rage across Los Angeles area, with death toll expected to rise . Forecasters expect fast, dry winds to return towards the end of the weekend, threatening to fuel fires that have already destroyed 10,000 structures and killed 16 people .
#
# Title: In utterly unsurprising news, Maga blames diversity for the Los Angeles wildfires | Arwa Mahdawi
# Link: https://www.theguardian.com/commentisfree/2025/jan/11/los-angeles-wildfires-diversity
# Summary:  Elon Musk, one of the brightest minds of his generation, is saying it, so it must be true . He says women are to blame for the devastating wildfires in California .
#
# ...

# %%
def fetch_and_summarize_bbc():
    # Fetch articles from BBC's RSS feed
    rss_url_bbc = "http://feeds.bbci.co.uk/news/science_and_environment/rss.xml"
    feed_bbc = feedparser.parse(rss_url_bbc)

    print("\n--- BBC Articles ---\n")
    for entry in feed_bbc.entries[:5]:  # Limit to 5 articles
        title = entry.title
        link = entry.link
        content = entry.summary

        # Generate a short summary
        summary = summarizer(content, max_length=100, min_length=30, do_sample=False)

        # Display the result
        print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# %%
fetch_and_summarize_bbc()
# Out:
# Your max_length is set to 100, but your input_length is only 21. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# --- BBC Articles ---
# Your max_length is set to 100, but your input_length is only 29. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Title: 2024 first year to pass 1.5C global warming limit
# Link: https://www.bbc.com/news/articles/cd7575x8yq5o
# Summary:  Last year was the world's warmest on record, bringing temperatures above a politically symbolic milestone . Last year's temperature was the highest in the world on record .
# ...

# %%
if len(content.split()) < 30:
    print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
else:
    summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
    print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-753279e8d37c> in <cell line: 1>()
# ----> 1 if len(content.split()) < 30:
#       2     print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
#       3 else:
#       4     summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
#       5     print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")
#
# NameError: name 'content' is not defined

# %%
def fetch_and_summarize_bbc():
    # Fetch articles from BBC's RSS feed
    rss_url_bbc = "http://feeds.bbci.co.uk/news/science_and_environment/rss.xml"
    feed_bbc = feedparser.parse(rss_url_bbc)

    print("\n--- BBC Articles ---\n")
    for entry in feed_bbc.entries[:5]:  # Limit to 5 articles
        title = entry.title
        link = entry.link
        content = entry.summary

        # Check if the article is very short (fewer than 30 words)
        if len(content.split()) < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            # Generate a short summary
            summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# %%
fetch_and_summarize_bbc()
# Out:
# --- BBC Articles ---
#
# Title: 2024 first year to pass 1.5C global warming limit
# Link: https://www.bbc.com/news/articles/cd7575x8yq5o
# Summary: Last year was the world's warmest on record, bringing temperatures above a politically symbolic milestone.
#
# Title: Million year-old bubbles could solve ice age mystery
# Link: https://www.bbc.com/news/articles/cwypyg4vq8ko
# Summary: What is probably the world's oldest ice, dating back 1.2m years ago, has been dug out from deep within Antarctica.
#
# Title: New images of Mercury captured by UK spacecraft
# Link: https://www.bbc.com/news/articles/cx2v2r1jm7go
# Summary: Stevenage-built BepiColombo makes final flyby of Mercury ahead of entering the plant's orbit in 2026.
#
# Title: How a freak space junk crash baffled residents and sparked concern
# Link: https://www.bbc.com/news/articles/clyn9dgdwe3o
# Summary: The Kenyan villagers surprised by falling satellite debris heralding a new year full of surprises.
#
# ...

# %%
import requests

def fetch_and_summarize_nyt():
    # Replace with your actual NYT API key
    nyt_api_key = "YOUR_API_KEY"
    nyt_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q=climate&api-key={nyt_api_key}"

    response = requests.get(nyt_url)
    articles = response.json()["response"]["docs"]

    print("\n--- New York Times Articles ---\n")
    for article in articles[:5]:  # Limit to 5 articles
        title = article["headline"]["main"]
        link = article["web_url"]
        content = article["abstract"] or article["lead_paragraph"]

        # Generate a short summary
        summary = summarizer(content, max_length=100, min_length=30, do_sample=False)

        # Display the result
        print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# %%
fetch_and_summarize_nyt()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-26335c9cac60> in <cell line: 1>()
# ----> 1 fetch_and_summarize_nyt()
#
# <ipython-input-33-ba77255ebeb7> in fetch_and_summarize_nyt()
#       7
#       8     response = requests.get(nyt_url)
# ----> 9     articles = response.json()["response"]["docs"]
#      10
#      11     print("\n--- New York Times Articles ---\n")
#
# KeyError: 'response'

# %%
import requests

def fetch_and_summarize_nyt():
    # Replace 'YOUR_API_KEY' with your actual NYT API key
    nyt_api_key ="DAJ2WuoaWXAelIxevdZjmU8rMAhuGbzM"
    nyt_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q=climate&api-key={nyt_api_key}"

    response = requests.get(nyt_url)
    articles = response.json()["response"]["docs"]

    print("\n--- New York Times Articles ---\n")
    for article in articles[:5]:  # Limit to 5 articles
        title = article["headline"]["main"]
        link = article["web_url"]
        content = article["abstract"] or article["lead_paragraph"]

        # Check if the article is very short (fewer than 30 words)
        if len(content.split()) < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            # Generate a short summary
            summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# %%
fetch_and_summarize_nyt()
# Out:
# --- New York Times Articles ---
#
# Title: L.A. Fires Show Limits of America’s Efforts to Cope With Climate Change
# Link: https://www.nytimes.com/2025/01/10/climate/california-fires-climate-change.html
# Summary: California has focused on fortifying communities against wildfires. But with growing threats, that may not be enough.
#
# Title: A Key Part of Biden’s Climate Law Was Built to Survive Trump. Now, the Test.
# Link: https://www.nytimes.com/2025/01/07/climate/ira-renewable-energy-tax-credits.html
# Summary: A lucrative tax credit for renewable energy could be hard to kill because it applies to a technologies favored by Republicans, not just wind and solar.
#
# Title: ‘We’re in a New Era’: How Climate Change Is Supercharging Disasters
# Link: https://www.nytimes.com/2025/01/10/climate/california-fires-climate-change-disasters.html
# Summary: Extreme weather events — deadly heat waves, floods, fires and hurricanes — are the consequences of a warming planet, scientists say.
#
# ...

# %%
def fetch_and_summarize_cnn():
    # Fetch articles from CNN's RSS feed
    rss_url_cnn = "http://rss.cnn.com/rss/edition_technology.rss"
    feed_cnn = feedparser.parse(rss_url_cnn)

    print("\n--- CNN Articles ---\n")
    for entry in feed_cnn.entries[:5]:  # Limit to 5 articles
        title = entry.title
        link = entry.link
        content = entry.summary

        # Check if the article is very short (fewer than 30 words)
        if len(content.split()) < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            # Generate a short summary
            summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# %%
fetch_and_summarize_cnn()
# Out:
# --- CNN Articles ---
#
# Title: How to outsmart fake news in your Facebook feed
# Link: http://www.cnn.com/2016/11/18/tech/how-to-spot-fake-misleading-news-trnd/index.html?eref=rss_tech
# Summary: Fake news is actually really easy to spot -- if you know how. Consider this your New Media Literacy Guide.
#
# Title: Revealed: Winners of the 'Oscars of watches'
# Link: http://www.cnn.com/2016/11/18/luxury/grand-prix-horlogerie-oscars-of-watches-2016/index.html?eref=rss_tech
# Summary: It's the prize giving ceremony that everyone's on time for.
#
# Title: Driverless 'Roborace' car makes street track debut
# Link: http://www.cnn.com/2016/11/18/motorsport/roborace-marrakech-cop22-formula-e/index.html?eref=rss_tech
# Summary: It is a car kitted out with technology its developers boldly predict will transform our cities and change the way we live.
#
# Title: Flying a sports car with wings
# Link: http://www.cnn.com/2016/11/18/aviation/sports-car-with-wings-icon-a5/index.html?eref=rss_tech
# ...

# %%
def fetch_and_summarize_yonhap():
    # Fetch articles from Yonhap News' RSS feed
    rss_url_yonhap = "https://www.yonhapnewstv.co.kr/environment/feed/"
    feed_yonhap = feedparser.parse(rss_url_yonhap)

    print("\n--- Yonhap News Articles ---\n")
    for entry in feed_yonhap.entries[:5]:  # Limit to 5 articles
        title = entry.title
        link = entry.link
        content = entry.summary

        # Check if the article is very short (fewer than 30 words)
        if len(content.split()) < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            # Generate a short summary
            summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# %%
fetch_and_summarize_yonhap()
# Out:
# --- Yonhap News Articles ---

# %%
def fetch_all_sources():
    print("\n=== Fetching articles from all sources ===\n")

    fetch_guardian()
    fetch_bbc()
    fetch_nyt()
    fetch_cnn()
    fetch_yonhap()

# %%
fetch_all_sources()
# Out:
# === Fetching articles from all sources ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-2baf9b51f5c3> in <cell line: 1>()
# ----> 1 fetch_all_sources()
#
# <ipython-input-49-57fdcdb17850> in fetch_all_sources()
#       2     print("\n=== Fetching articles from all sources ===\n")
#       3
# ----> 4     fetch_guardian()
#       5     fetch_bbc()
#       6     fetch_nyt()
#
# NameError: name 'fetch_guardian' is not defined

# %%
import feedparser
from transformers import pipeline

# Initialize the summarizer
summarizer = pipeline("summarization")

def fetch_guardian():
    rss_url_guardian = "https://www.theguardian.com/environment/rss"
    feed_guardian = feedparser.parse(rss_url_guardian)

    print("\n--- The Guardian Articles ---\n")
    for entry in feed_guardian.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
        print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

def fetch_bbc():
    rss_url_bbc = "http://feeds.bbci.co.uk/news/science_and_environment/rss.xml"
    feed_bbc = feedparser.parse(rss_url_bbc)

    print("\n--- BBC Articles ---\n")
    for entry in feed_bbc.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        if len(content.split()) < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

def fetch_nyt():
    import requests
    nyt_api_key = "DAJ2WuoaWXAelIxevdZjmU8rMAhuGbzM"
    nyt_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q=climate&api-key={nyt_api_key}"

    response = requests.get(nyt_url)
    articles = response.json()["response"]["docs"]

    print("\n--- New York Times Articles ---\n")
    for article in articles[:5]:
        title = article["headline"]["main"]
        link = article["web_url"]
        content = article["abstract"] or article["lead_paragraph"]
        summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
        print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

def fetch_cnn():
    rss_url_cnn = "http://rss.cnn.com/rss/edition_technology.rss"
    feed_cnn = feedparser.parse(rss_url_cnn)

    print("\n--- CNN Articles ---\n")
    for entry in feed_cnn.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        if len(content.split()) < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

def fetch_yonhap():
    rss_url_yonhap = "https://www.yonhapnewstv.co.kr/environment/feed/"
    feed_yonhap = feedparser.parse(rss_url_yonhap)

    print("\n--- Yonhap News Articles ---\n")
    for entry in feed_yonhap.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        if len(content.split()) < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            summary = summarizer(content, max_length=100, min_length=30, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
def fetch_all_sources():
    print("\n=== Fetching articles from all sources ===\n")

    fetch_guardian()
    fetch_bbc()
    fetch_nyt()
    fetch_cnn()
    fetch_yonhap()

# %%
fetch_all_sources()
# Out:
# === Fetching articles from all sources ===
#
#
# --- The Guardian Articles ---
#
# Title: California fires: 16 killed and 10,000 structures destroyed as blazes continue
# Link: https://www.theguardian.com/us-news/2025/jan/10/fast-dry-winds-california-wildfires
# Summary:  Strong winds and low humidity continue as five fires rage across Los Angeles area, with death toll expected to rise . Forecasters expect fast, dry winds to return towards the end of the weekend, threatening to fuel fires that have already destroyed 10,000 structures and killed 16 people .
#
# Title: In utterly unsurprising news, Maga blames diversity for the Los Angeles wildfires | Arwa Mahdawi
# Link: https://www.theguardian.com/commentisfree/2025/jan/11/los-angeles-wildfires-diversity
# Summary:  Elon Musk, one of the brightest minds of his generation, is saying it, so it must be true . He says women are to blame for the devastating wildfires in California .
#
# ...

# %%
# Install required libraries
# !pip install newspaper3k feedparser transformers pdfminer.six schedule requests

# Import necessary libraries
import feedparser
from transformers import pipeline
import requests

# Initialize the summarizer
summarizer = pipeline("summarization")

# Function to fetch and summarize articles from The Guardian
def fetch_guardian():
    rss_url_guardian = "https://www.theguardian.com/environment/rss"
    feed_guardian = feedparser.parse(rss_url_guardian)

    print("\n--- The Guardian Articles ---\n")
    for entry in feed_guardian.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        input_length = len(content.split())
        max_length = min(100, int(input_length * 0.7))
        summary = summarizer(content, max_length=max_length, min_length=10, do_sample=False)
        print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# Function to fetch and summarize articles from BBC
def fetch_bbc():
    rss_url_bbc = "http://feeds.bbci.co.uk/news/science_and_environment/rss.xml"
    feed_bbc = feedparser.parse(rss_url_bbc)

    print("\n--- BBC Articles ---\n")
    for entry in feed_bbc.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        input_length = len(content.split())
        max_length = min(100, int(input_length * 0.7))
        if input_length < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            summary = summarizer(content, max_length=max_length, min_length=10, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# Function to fetch and summarize articles from The New York Times
def fetch_nyt():
    nyt_api_key = "DAJ2WuoaWXAelIxevdZjmU8rMAhuGbzM"
    nyt_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q=climate&api-key={nyt_api_key}"

    response = requests.get(nyt_url)
    articles = response.json().get("response", {}).get("docs", [])

    print("\n--- New York Times Articles ---\n")
    for article in articles[:5]:
        title = article["headline"]["main"]
        link = article["web_url"]
        content = article.get("abstract") or article.get("lead_paragraph")
        input_length = len(content.split())
        max_length = min(100, int(input_length * 0.7))
        summary = summarizer(content, max_length=max_length, min_length=10, do_sample=False)
        print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# Function to fetch and summarize articles from CNN
def fetch_cnn():
    rss_url_cnn = "http://rss.cnn.com/rss/edition_technology.rss"
    feed_cnn = feedparser.parse(rss_url_cnn)

    print("\n--- CNN Articles ---\n")
    for entry in feed_cnn.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        input_length = len(content.split())
        max_length = min(100, int(input_length * 0.7))
        if input_length < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            summary = summarizer(content, max_length=max_length, min_length=10, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# Function to fetch and summarize articles from Yonhap News
def fetch_yonhap():
    rss_url_yonhap = "https://www.yonhapnewstv.co.kr/environment/feed/"
    feed_yonhap = feedparser.parse(rss_url_yonhap)

    print("\n--- Yonhap News Articles ---\n")
    for entry in feed_yonhap.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        input_length = len(content.split())
        max_length = min(100, int(input_length * 0.7))
        if input_length < 30:
            print(f"Title: {title}\nLink: {link}\nSummary: {content}\n")
        else:
            summary = summarizer(content, max_length=max_length, min_length=10, do_sample=False)
            print(f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n")

# Master function to fetch and summarize articles from all sources
def fetch_all_sources():
    print("\n=== Fetching articles from all sources ===\n")

    summaries = []  # List to collect all summaries

    summaries.append("=== The Guardian ===\n")
    fetch_guardian()

    summaries.append("=== BBC ===\n")
    fetch_bbc()

    summaries.append("=== New York Times ===\n")
    fetch_nyt()

    summaries.append("=== CNN ===\n")
    fetch_cnn()

    summaries.append("=== Yonhap News ===\n")
    fetch_yonhap()

    # Combine all summaries into one string
    summary_text = "\n".join(summaries)

    # Send the combined summary via email
    send_email(summary_text)


# Run the master function
fetch_all_sources()
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 46.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 87.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 7.1 MB/s eta 0:00:00
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13539 sha256=34c6e663ea5b50627c8aec321698a8e7a5e09d0435a1bb3cd8a685c67157ac35
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
# ...

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

def send_email(summary_text):
    sender_email = "kjk1020@gmail.com"  # Your email
    receiver_email = "kjk1020@gmail.com"  # Recipient email
    password = "nyeu xlqp kzto bjnc"  # Replace this with your 16-character app password

    # Create the email message
    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = "Daily News Summary"

    # Attach the summary text
    message.attach(MIMEText(summary_text, "plain"))

    # Send the email
    with smtplib.SMTP("smtp.gmail.com", 587) as server:
        server.starttls()
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, message.as_string())

    print("Email sent successfully!")

# %%
with smtplib.SMTP("smtp.gmail.com", 587) as server:
    server.starttls()
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message.as_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2ac936175f75> in <cell line: 1>()
#       1 with smtplib.SMTP("smtp.gmail.com", 587) as server:
#       2     server.starttls()
# ----> 3     server.login(sender_email, password)
#       4     server.sendmail(sender_email, receiver_email, message.as_string())
#
# NameError: name 'sender_email' is not defined

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

def send_email(summary_text):
    sender_email = "kjk1020@gmail.com"  # Your email
    receiver_email = "kjk1020@gmail.com"  # Recipient email (can be the same as sender)
    password = "nyeu xlqp kzto bjnc"  # Replace with your actual 16-character app password

    # Create the email message
    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = "Daily News Summary"

    # Attach the summary text
    message.attach(MIMEText(summary_text, "plain"))

    # Send the email
    with smtplib.SMTP("smtp.gmail.com", 587) as server:
        server.starttls()
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, message.as_string())

    print("Email sent successfully!")

# %%
summary_text = "This is a test email. Replace this with actual news summary."
send_email(summary_text)
# Out:
# Email sent successfully!

# %%
# Install required libraries
# !pip install newspaper3k feedparser transformers pdfminer.six schedule requests

# Import necessary libraries
import feedparser
from transformers import pipeline
import requests
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Initialize the summarizer
summarizer = pipeline("summarization")

# Function to send email
def send_email(summary_text):
    sender_email = "kjk1020@gmail.com"  # Your email
    receiver_email = "kjk1020@gmail.com"  # Recipient email
    password = "nyeu xlqp kzto bjnc"  # Replace with your actual 16-character app password

    # Create the email message
    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = "Daily News Summary"

    # Attach the summary text
    message.attach(MIMEText(summary_text, "plain"))

    # Send the email
    with smtplib.SMTP("smtp.gmail.com", 587) as server:
        server.starttls()
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, message.as_string())

    print("Email sent successfully!")

# Function to fetch and summarize articles from The Guardian
def fetch_guardian():
    rss_url_guardian = "https://www.theguardian.com/environment/rss"
    feed_guardian = feedparser.parse(rss_url_guardian)

    result = "\n--- The Guardian Articles ---\n"
    for entry in feed_guardian.entries[:5]:
      title = entry.title
      link = entry.link
      content = entry.summary
      input_length = len(content.split())
      max_length = min(200, int(input_length * 1.0))
      if input_length < 50:
          result += f"Title: {title}\nLink: {link}\nSummary: {content}\n\n"
      else:
          summary = summarizer(content, max_length=max_length, min_length=50, do_sample=False)
          result += f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n\n"

    return result

# Function to fetch and summarize articles from BBC
def fetch_bbc():
    rss_url_bbc = "http://feeds.bbci.co.uk/news/science_and_environment/rss.xml"
    feed_bbc = feedparser.parse(rss_url_bbc)

    result = "\n--- BBC Articles ---\n"
    for entry in feed_bbc.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        input_length = len(content.split())
        max_length = min(200, int(input_length * 1.0))
        if input_length < 50:
            result += f"Title: {title}\nLink: {link}\nSummary: {content}\n\n"
        else:
            summary = summarizer(content, max_length=max_length, min_length=50, do_sample=False)
            result += f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n\n"

    return result

# Function to fetch and summarize articles from The New York Times
def fetch_nyt():
    nyt_api_key = "DAJ2WuoaWXAelIxevdZjmU8rMAhuGbzM"  # Replace with your actual NYT API key
    nyt_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q=climate&api-key={nyt_api_key}"

    response = requests.get(nyt_url)
    articles = response.json().get("response", {}).get("docs", [])

    result = "\n--- New York Times Articles ---\n"
    for article in articles[:5]:
        title = article["headline"]["main"]
        link = article["web_url"]
        content = article.get("abstract") or article.get("lead_paragraph")
        input_length = len(content.split())
        max_length = min(200, int(input_length * 1.0))
        summary = summarizer(content, max_length=max_length, min_length=50, do_sample=False)
        result += f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n\n"

    return result

# Function to fetch and summarize articles from CNN
def fetch_cnn():
    rss_url_cnn = "http://rss.cnn.com/rss/edition_technology.rss"
    feed_cnn = feedparser.parse(rss_url_cnn)

    result = "\n--- CNN Articles ---\n"
    for entry in feed_cnn.entries[:5]:
        title = entry.title
        link = entry.link
        content = entry.summary
        input_length = len(content.split())
        max_length = min(200, int(input_length * 1.0))
        if input_length < 50:
            result += f"Title: {title}\nLink: {link}\nSummary: {content}\n\n"
        else:
            summary = summarizer(content, max_length=max_length, min_length=50, do_sample=False)
            result += f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n\n"

    return result

# Function to fetch and summarize articles from Yonhap News
def fetch_yonhap():
    rss_url_yonhap = "https://www.yonhapnewstv.co.kr/environment/feed/"
    feed_yonhap = feedparser.parse(rss_url_yonhap)

    result = "\n--- Yonhap News Articles ---\n"
    for entry in feed_yonhap.entries[:5]:
      title = entry.title
      link = entry.link
      content = entry.summary
      input_length = len(content.split())
      max_length = min(200, int(input_length * 1.0))
      if input_length < 50:
          result += f"Title: {title}\nLink: {link}\nSummary: {content}\n\n"
      else:
          summary = summarizer(content, max_length=max_length, min_length=50, do_sample=False)
          result += f"Title: {title}\nLink: {link}\nSummary: {summary[0]['summary_text']}\n\n"

    return result

# Master function to fetch and summarize articles from all sources
def fetch_all_sources():
    print("\n=== Fetching articles from all sources ===\n")

    summaries = []  # List to collect all summaries

    summaries.append(fetch_guardian())
    summaries.append(fetch_bbc())
    summaries.append(fetch_nyt())
    summaries.append(fetch_cnn())
    summaries.append(fetch_yonhap())

    # Combine all summaries into one string
    summary_text = "\n".join(summaries)

    # Send the combined summary via email
    send_email(summary_text)

# Run the master function
fetch_all_sources()
# Out:
# ...
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# === Fetching articles from all sources ===
# Your min_length=50 must be inferior than your max_length=17.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1427: UserWarning: Unfeasible length constraints: `min_length` (50) is larger than the maximum possible length (17). Generation will stop at the defined maximum length. You should decrease the minimum length and/or increase the maximum length.
#   warnings.warn(
# Your min_length=50 must be inferior than your max_length=26.
# ...
